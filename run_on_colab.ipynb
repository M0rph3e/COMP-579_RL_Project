# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
#@title Mount your Google Drive
# If you run this notebook locally or on a cluster (i.e. not on Google Colab)
# you can delete this cell which is specific to Google Colab. You may also
# change the paths for data/logs in Arguments below.
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
''
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#@title Link your assignment folder & install requirements
#@markdown Enter the path to the assignment folder in your Google Drive
# If you run this notebook locally or on a cluster (i.e. not on Google Colab)
# you can delete this cell which is specific to Google Colab. You may also
# change the paths for data/logs in Arguments below.
import sys
import os
import shutil
import warnings

folder = "/COMP-579_RL_Project" #@param {type:"string"}
# !ln -Ts "$folder" /content/src 2> /dev/null

# Add the assignment folder to Python path
if '/content/src' not in sys.path:
  sys.path.insert(0, '/content/src')

# Install requirements
#!pip install -qr /content/assignment/requirements.txt

# Check if CUDA is available
import torch
if not torch.cuda.is_available():
  warnings.warn('CUDA is not available.')
# Out:
# <ipython-input-3-ab3eb0b3e586>:24: UserWarning: CUDA is not available.
#   warnings.warn('CUDA is not available.')

# %% [markdown]
# ## Install and import

# %% [markdown]
# need to have a version lower than 0.21 (for some reason v17.0 works)

# %%
# !pip install gym-super-mario-bros
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.0 MB/s eta 0:00:00
# ...
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp310-cp310-linux_x86_64.whl size=494872 sha256=e15b7e0081f47aaf3fc283c362955a7c65ba98a9eca77de53b98b926e7f7010c
#   Stored in directory: /root/.cache/pip/wheels/34/a7/d5/9aa14b15df740a53d41f702e4c795731b6c4da7925deb8476c
# Successfully built nes-py
# ...

# %%
# !pip uninstall gym -y
# Out:
# Found existing installation: gym 0.25.2
# Uninstalling gym-0.25.2:
#   Successfully uninstalled gym-0.25.2

# %%
# !pip install --force-reinstall -v gym==0.17.0
# Out:
# Using pip 23.0.1 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.6 MB/s eta 0:00:00
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info
#   writing /tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-rb3gnt8p/gym.egg-info/SOURCES.txt'
# ...

# %%
# %cd src
# Out:
# [autoreload of six failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     old_obj = getattr(old, key)
#   File "/usr/local/lib/python3.10/dist-packages/six.py", line 98, in __get__
#     setattr(obj, self.name, result)  # Invokes __set__.
# AttributeError: 'NoneType' object has no attribute 'filter'
# ]
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
# ...

# %% [markdown]
# ## Run experiments

# %%
import gym
gym.__version__ # if doesn't change restart execution env
# Out:
# '0.17.0'

# %%
# !python compare.py
# Out:
# Loading model at trained_mario_ddqn.chkpt with exploration rate 0.1
# Loading model at trained_mario_pg.pth
# Episode 0 - Step 1634 - Epsilon 0.1 - Mean Reward 812.0 - Mean Length 1634.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 30.608 - Time 2023-04-27T17:29:24
# Episode 10 - Step 23141 - Epsilon 0.1 - Mean Reward 329.455 - Mean Length 2103.727 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 408.717 - Time 2023-04-27T17:36:13
# Episode 20 - Step 42037 - Epsilon 0.1 - Mean Reward 325.048 - Mean Length 2001.762 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 353.685 - Time 2023-04-27T17:42:07
# Episode 30 - Step 55868 - Epsilon 0.1 - Mean Reward 374.774 - Mean Length 1802.194 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 258.792 - Time 2023-04-27T17:46:25
# Episode 40 - Step 73864 - Epsilon 0.1 - Mean Reward 361.732 - Mean Length 1801.561 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 334.265 - Time 2023-04-27T17:52:00
# ...

# %%
while True:pass
